# %%
pip install numpy pandas scipy matplotlib seaborn jupyter
# Out:
# Requirement already satisfied: numpy in c:\users\andik\.conda\envs\main-ds\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\andik\.conda\envs\main-ds\lib\site-packages (2.2.3)
# Requirement already satisfied: scipy in c:\users\andik\.conda\envs\main-ds\lib\site-packages (1.13.1)
# Requirement already satisfied: matplotlib in c:\users\andik\.conda\envs\main-ds\lib\site-packages (3.9.4)
# Requirement already satisfied: seaborn in c:\users\andik\.conda\envs\main-ds\lib\site-packages (0.13.2)
# Requirement already satisfied: jupyter in c:\users\andik\.conda\envs\main-ds\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: notebook in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter) (4.3.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (1.8.13)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (8.18.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-console->jupyter) (3.0.50)
# Requirement already satisfied: pygments in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-console->jupyter) (2.19.1)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (8.6.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (75.8.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (4.13.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from async-lru>=1.0.0->jupyterlab->jupyter) (4.12.2)
# Requirement already satisfied: webencodings in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: anyio in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.8.0)
# Requirement already satisfied: certifi in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.7)
# Requirement already satisfied: idna in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: decorator in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack-data in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: exceptiongroup in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.2.2)
# Requirement already satisfied: colorama in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (307)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.15)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: wcwidth in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\andik\.conda\envs\main-ds\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/customers.csv")
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
product_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/products.csv")
product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# ## Assesing Data

# %% [markdown]
# ### Menilai Data Customers

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %% [markdown]
# ### Menilai Data Orders

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
orders_df.isna().sum()
# Out:
# order_id         0
# customer_id      0
# payment          0
# order_date       0
# delivery_date    0
# dtype: int64

# %%
print("Jumlah duplikasi: ", orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
orders_df.describe()
# Out:
#           order_id  customer_id       payment
# count  1000.000000  1000.000000   1000.000000
# mean    500.500000   506.640000  33972.936000
# std     288.819436   277.115502  14451.609047
# min       1.000000     1.000000  10043.000000
# 25%     250.750000   275.250000  21329.250000
# 50%     500.500000   515.000000  33697.500000
# 75%     750.250000   737.250000  46249.000000
# max    1000.000000  1000.000000  59910.000000

# %% [markdown]
# ### Menilai Data Product

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.2+ KB

# %%
product_df.isna().sum()
# Out:
# product_id      0
# product_type    0
# product_name    0
# size            0
# colour          0
# price           0
# quantity        0
# description     0
# dtype: int64

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
product_df.describe()
# Out:
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %% [markdown]
# ### Menilai Data Sales

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# ### Kesimpulan Assesing Data
#   Tabel Data | Tipe Data | Missing Value | Duplicate Data | Inaccurate Value
#   --- | --- | --- | --- | --- |
#   customers_df | - | Terdapat 18 missing values pada kolom gender. | Terdapat 6 data yang duplikat. | Terdapat inaccurate value pada kolom age.
#   orders_df | Terdapat kesalahan tipe data untuk kolom order_date & delivery_date. | - | - | -
#   product_df | - | - | Terdapat 6 data yang duplikat. | -
#   sales_df | - | Terdapat 19 missing value pada kolom total_price. | - | -

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# ### Membersihkan Data Customers

# %% [markdown]
# #### Menghapus Data Duplikasi

# %%
customers_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# #### Menangani Missing Value

# %%
customers_df[customers_df.gender.isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# 859          855     fulan 855    NaN   55       603 O'keefe KnollSuite 782
# 863          859     fulan 859    NaN   38            32 Isla GroveApt. 078
# 914          909     fulan 909    NaN   62    976 Murray Station StApt. 036
# 934          929     fulan 929    NaN   68           394 Lily HillSuite 153
# 948          943     fulan 943    NaN   64       3117 Heller PlaceSuite 149
# 952          946     fulan 946    NaN   24      8227 Nicholas HillSuite 150
# 994          988     fulan 988    NaN   35   1130 Turner Estate DrSuite 925
#
#      zip_code                   city                         state    country
# 38       4622  North Victoriachester            Northern Territory  Australia
# 167      1975         North Leoburgh             Western Australia  Australia
# 322      1640             Jacobiview             Western Australia  Australia
# 393      1474             Johnsburgh                    Queensland  Australia
# 442      7249             Port Chloe               New South Wales  Australia
# 722      1380             West Henry               South Australia  Australia
# 745      6226         Lake Lukemouth             Western Australia  Australia
# 773      8882               Kuhntown                      Victoria  Australia
# 798      1712            East Hayden  Australian Capital Territory  Australia
# 801      6531               Port Sam  Australian Capital Territory  Australia
# 825      2588        Lake Andrewport               South Australia  Australia
# 859      8822        Port Dylanmouth                      Tasmania  Australia
# 863      7711            Rosechester               New South Wales  Australia
# 914      3227               Langfort                      Tasmania  Australia
# 934      2353             Beahanfurt            Northern Territory  Australia
# 948       822           North Elijah               South Australia  Australia
# 952       115           South Jasper                    Queensland  Australia
# 994      9386              New Harry             Western Australia  Australia

# %%
customers_df.gender.value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
customers_df.fillna(value="Prefer not to say", inplace=True)

# %%
customers_df.isna().sum()
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %% [markdown]
# #### Menangani Inaccurate Value

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %%
customers_df.age.replace(customers_df.age.max(), 70, inplace=True)
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\4147959128.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 70, inplace=True)

# %%
customers_df[customers_df.age == customers_df.age.max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %%
customers_df.age.replace(customers_df.age.max(), 50, inplace=True)
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\606824494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   customers_df.age.replace(customers_df.age.max(), 50, inplace=True)

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1001.000000  1001.000000  1001.000000
# mean    500.942058    49.874126  5000.693307
# std     289.013599    17.644663  2886.084454
# min       1.000000    20.000000     2.000000
# 25%     251.000000    34.000000  2398.000000
# 50%     501.000000    50.000000  5079.000000
# 75%     751.000000    65.000000  7454.000000
# max    1000.000000    80.000000  9998.000000

# %% [markdown]
# ### Membersihkan Data Orders

# %% [markdown]
# #### Menangani Tipe Data

# %%
datetime_columns = ["order_date", "delivery_date"]
 
for column in datetime_columns:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %% [markdown]
# ### Membersihkan Data Product

# %% [markdown]
# #### Menghapus Data Duplikasi

# %%
product_df.drop_duplicates(inplace=True)

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %% [markdown]
# ### Membersihkan Data Sales

# %% [markdown]
# #### Menangani Missing Value

# %%
sales_df[sales_df.total_price.isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# 1313      1313       272         826             117         1          NaN
# 1548      1548       316         103             118         3          NaN
# 1688      1688       345         428             107         1          NaN
# 1775      1775       359         694             113         2          NaN
# 1902      1902       381        1218             105         3          NaN
# 2025      2025       408         611             112         3          NaN
# 2164      2164       436         583             100         3          NaN
# 2347      2347       476         696             113         2          NaN

# %%
sales_df["total_price"] = sales_df["price_per_unit"] * sales_df["quantity"]

# %%
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Eksplorasi Data Customers

# %%
customers_df.describe(include="all")
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code         city            state  \
# count                         1001  1001.000000         1001             1001
# unique                        1000          NaN          961                8
# top     3117 Heller PlaceSuite 149          NaN  East Sophia  South Australia
# freq                             2          NaN            3              140
# mean                           NaN  5000.693307          NaN              NaN
# std                            NaN  2886.084454          NaN              NaN
# min                            NaN     2.000000          NaN              NaN
# 25%                            NaN  2398.000000          NaN              NaN
# 50%                            NaN  5079.000000          NaN              NaN
# 75%                            NaN  7454.000000          NaN              NaN
# max                            NaN  9998.000000          NaN              NaN
#
#           country
# count        1001
# unique          1
# top     Australia
# freq         1001
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
customers_df.groupby(by="gender").agg({
    "customer_id": "nunique",
    "age": ["max", "min", "mean", "std"]
})
# Out:
#                   customer_id age
#                       nunique max min       mean        std
# gender
# Female                    115  79  20  49.147826  16.646607
# Male                      143  80  20  51.230769  18.462635
# Prefer not to say         742  80  20  49.725437  17.644283

# %%
customers_df.groupby(by="city").customer_id.nunique().sort_values(ascending=False)
# Out:
# city
# East Aidan         3
# East Sophia        3
# New Ava            3
# Lake Rose          2
# Chloeville         2
#                   ..
# Youngview          1
# Zacharyborough     1
# Andersonchester    1
# Zacshire           1
# Ameliaview         1
# Name: customer_id, Length: 961, dtype: int64

# %%
customers_df.groupby(by="state").customer_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# ## Eksplorasi Data Orders

# %%
delivery_time = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time = delivery_time.apply(lambda x: x.total_seconds())
orders_df["delivery_time"] = round(delivery_time/86400)

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0

# %%
orders_df.describe(include="all")
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time
# count                 1000    1000.000000
# mean   2021-06-10 20:31:12      14.078000
# min    2021-01-03 00:00:00       1.000000
# 25%    2021-03-28 00:00:00       8.000000
# 50%    2021-06-11 12:00:00      14.000000
# 75%    2021-08-24 06:00:00      21.000000
# max    2021-11-20 00:00:00      27.000000
# std                    NaN       7.707225

# %% [markdown]
# ## Eksplorasi Data Orders dan Customers

# %%
customer_id_in_orders_df =  orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#       customer_id customer_name             gender  age  \
# 1000          994     fulan 994             Female   53
# 186           187     fulan 187  Prefer not to say   70
# 663           662     fulan 662             Female   58
# 182           183     fulan 183             Female   44
# 636           635     fulan 635               Male   59
#
#                        home_address  zip_code            city  \
# 1000       3128 Ivy CircleSuite 713       508       Hallshire
# 186    30 Williamson SummitApt. 594      1007  West Isabelton
# 663       8986 Alice IslandApt. 026      3207      Pipershire
# 182   639 Griffiths ParkwayApt. 162      9583    New Angelina
# 636      022 Jade Estate DrApt. 494      4796       Adamsland
#
#                   state    country      status
# 1000  Western Australia  Australia      Active
# 186          Queensland  Australia      Active
# 663          Queensland  Australia      Active
# 182          Queensland  Australia      Active
# 636     New South Wales  Australia  Non Active

# %%
customers_df.groupby(by="status").customer_id.count()
# Out:
# status
# Active        617
# Non Active    384
# Name: customer_id, dtype: int64

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  delivery_time  \
# 0         1           64    30811 2021-08-30    2021-09-24           25.0
# 1         2          473    50490 2021-02-03    2021-02-13           10.0
# 2         3          774    46763 2021-10-08    2021-11-03           26.0
# 3         4          433    39782 2021-05-06    2021-05-19           13.0
# 4         5          441    14719 2021-03-23    2021-03-24            1.0
#
#   customer_name             gender  age                   home_address  \
# 0      fulan 64  Prefer not to say   75      4927 Alice MeadowApt. 960
# 1     fulan 473               Male   61  531 Schmitt BoulevardApt. 010
# 2     fulan 774  Prefer not to say   34       2096 Wilson MewsApt. 714
# 3     fulan 433  Prefer not to say   46        5777 Mayer PassApt. 881
# 4     fulan 441  Prefer not to say   53   33 Richards JunctionApt. 478
#
#    zip_code                city              state    country  status
# 0      7787      Sanfordborough    South Australia  Australia  Active
# 1      1744             Annaton    South Australia  Australia  Active
# 2      8590  West Jonathanshire           Tasmania  Australia  Active
# 3      9728    West Michaelport           Tasmania  Australia  Active
# 4      7650     South Rileyview  Western Australia  Australia  Active

# %% [markdown]
# ### Jumlah Order Berdasarkan Kota

# %%
orders_customers_df.groupby(by="city").order_id.nunique().sort_values(ascending=False).reset_index().head(10)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2  Port Hannahburgh         5
# 3         Lake Rose         5
# 4        O'keefeton         5
# 5          East Max         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8         Sarahstad         4
# 9        Russelstad         4

# %% [markdown]
# ### Jumlah Order Berdasarkan State

# %%
orders_customers_df.groupby(by="state").order_id.nunique().sort_values(ascending=False)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Victoria                        118
# Australian Capital Territory    118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %% [markdown]
# ### Jumlah Order Berdasarkan Gender

# %%
orders_customers_df.groupby(by="gender").order_id.nunique().sort_values(ascending=False)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# ### Jumlah Order Berdasarkan Kelompok Usia

# %%
orders_customers_df["age_group"] = orders_customers_df.age.apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))
orders_customers_df.groupby(by="age_group").order_id.nunique().sort_values(ascending=False)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# ## Eksplorasi Data Product dan Sales

# %%
product_df.describe(include="all")
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                        description
# count   1260.000000                                               1260
# unique          NaN                                               1260
# top             NaN  A violet coloured, XL sized, Tracksuit Bottoms...
# freq            NaN                                                  1
# mean      60.150000                                                NaN
# std       11.670573                                                NaN
# min       40.000000                                                NaN
# 25%       50.000000                                                NaN
# 50%       60.000000                                                NaN
# 75%       70.000000                                                NaN
# max       80.000000                                                NaN

# %%
sales_df.describe(include="all")
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
product_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 671          665       Jacket        Parka   XS     red    119        65
# 672          666       Jacket        Parka    S     red    119        66
# 673          667       Jacket        Parka    M     red    119        56
# 674          668       Jacket        Parka    L     red    119        73
# 675          669       Jacket        Parka   XL     red    119        64
# ...          ...          ...          ...  ...     ...    ...       ...
# 1222        1216     Trousers      Pleated    S  indigo     90        41
# 1229        1223     Trousers      Pleated    L  violet     90        48
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1226        1220     Trousers      Pleated   XS  violet     90        58
#
#                                         description
# 671          A red coloured, XS sized, Parka Jacket
# 672           A red coloured, S sized, Parka Jacket
# 673           A red coloured, M sized, Parka Jacket
# 674           A red coloured, L sized, Parka Jacket
# 675          A red coloured, XL sized, Parka Jacket
# ...                                             ...
# 1222   A indigo coloured, S sized, Pleated Trousers
# 1229   A violet coloured, L sized, Pleated Trousers
# 1228   A violet coloured, M sized, Pleated Trousers
# 1227   A violet coloured, S sized, Pleated Trousers
# 1226  A violet coloured, XS sized, Pleated Trousers
#
# [1260 rows x 8 columns]

# %%
product_df.groupby(by="product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
product_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# Joggers                   35     2107    94   94
# Leather                   35     2276   113  113
# Linen                     35     2138   116  116
# Mandarin Collar           35     2203   108  108
# Oxford Cloth              35     2071   114  114
# Parka                     35     2201   119  119
# Peacoat                   35     2067   102  102
# Pleated                   35     2030    90   90
# Polo                      35     2196   117  117
# Puffer                    35     1946   110  110
# Pullover                  35     2184   114  114
# Relaxed Leg               35     2002    95   95
# Shearling                 35     2169    95   95
# Slim-Fit                  35     2155   119  119
# Tracksuit Bottoms         35     2038    91   91
# Trench Coat               35     2132   112  112
# Windbreaker               35     2085   109  109
# Wool                      35     1975   111  111

# %%
sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  price  quantity_y  \
# 0        Shirt      Chambray    L  orange    105          44
# 1       Jacket        Puffer    S  indigo    110          62
# 2        Shirt  Oxford Cloth    M     red    114          54
# 3     Trousers          Wool    M    blue    111          52
# 4       Jacket         Parka    S  indigo    119          53
#
#                                    description
# 0   A orange coloured, L sized, Chambray Shirt
# 1    A indigo coloured, S sized, Puffer Jacket
# 2  A red coloured, M sized, Oxford Cloth Shirt
# 3      A blue coloured, M sized, Wool Trousers
# 4     A indigo coloured, S sized, Parka Jacket

# %%
sales_product_df.groupby(by="product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Shirt             1641        3259       333600
# Trousers          1683        3360       341174

# %%
sales_product_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": "sum"
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# Tracksuit Bottoms       130         257        28784
# Slim-Fit                154         288        27936
# Oxford Cloth            146         289        27744
# Drawstring              147         288        27648
# High-Waisted            140         278        27522
# Camp Collared           139         279        27342
# Cargo Pants             134         267        27234
# Relaxed Leg             146         301        27090
# Cuban Collar            122         254        26670
# Henley                  146         281        26414
# Wool                    125         249        26394
# Leather                 136         263        25774
# Mandarin Collar         124         236        25724
# Dress                   127         243        25272
# Pullover                143         276        25116
# Polo                    131         264        25080
# Coach                   134         265        24645
# Linen                   131         270        24570
# Cords                   126         246        23124

# %% [markdown]
# ## Eksplorasi Data All

# %%
all_df = pd.merge(
    left=sales_product_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1         1         1         481             118           1          118
# 2         2         1           2              96           3          288
# 3         3         1        1002             106           2          212
# 4         4         1         691             113           3          339
#
#   product_type  product_name size  colour  ...  customer_name  \
# 0        Shirt      Chambray    L  orange  ...       fulan 64
# 1       Jacket        Puffer    S  indigo  ...       fulan 64
# 2        Shirt  Oxford Cloth    M     red  ...       fulan 64
# 3     Trousers          Wool    M    blue  ...       fulan 64
# 4       Jacket         Parka    S  indigo  ...       fulan 64
#
#               gender age               home_address  zip_code            city  \
# 0  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 1  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 2  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 3  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
# 4  Prefer not to say  75  4927 Alice MeadowApt. 960      7787  Sanfordborough
#
#              state    country  status age_group
# 0  South Australia  Australia  Active   Seniors
# 1  South Australia  Australia  Active   Seniors
# 2  South Australia  Australia  Active   Seniors
# 3  South Australia  Australia  Active   Seniors
# 4  South Australia  Australia  Active   Seniors
#
# [5 rows x 28 columns]

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# South Australia              Jacket               461        49090
#                              Shirt                509        52685
#                              Trousers             455        46041
# Tasmania                     Jacket               412        44370
#                              Shirt                387        39668
#                              Trousers             379        38057
# Victoria                     Jacket               359        38203
#                              Shirt                390        40206
#                              Trousers             414        41948
# Western Australia            Jacket               390        41659
#                              Shirt                393        40242
#                              Trousers             429        43529

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %%
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## 1. Bagaimana Performa Penjualan dan Revenue Perusahaan dalam Beberapa Bulan Terakhir?

# %%
monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\3369829290.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    95080
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597

# %%
plt.figure(figsize=(10, 5)) 
plt.plot(monthly_orders_df["order_date"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="#72BCD4") 
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20) 
plt.xticks(fontsize=10) 
plt.yticks(fontsize=10) 
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["revenue"],
    marker='o', 
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## 2. Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_df.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#        product_name  quantity_x
# 0             Denim         527
# 1           Joggers         334
# 2           Pleated         308
# 3   Casual Slim Fit         306
# 4         Shearling         302
# 5       Relaxed Leg         301
# 6       Trench Coat         299
# 7            Puffer         298
# 8            Bomber         297
# 9          Chambray         290
# 10     Oxford Cloth         289
# 11       Drawstring         288
# 12         Slim-Fit         288
# 13      Windbreaker         287
# 14          Cropped         284

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
 
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)
 
sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)
 
plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\3197072374.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\3197072374.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])

# %% [markdown]
# ## 3. Bagaimana demografi pelanggan yang kita miliki?

# %% [markdown]
# ### Berdasarkan Gender

# %%
bygender_df = all_df.groupby(by="gender").customer_id.nunique().reset_index()
bygender_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
 
plt.figure(figsize=(10, 5))
 
sns.barplot(
    y="customer_count", 
    x="gender",
    data=bygender_df.sort_values(by="customer_count", ascending=False),
    palette=colors
)
plt.title("Number of Customer by Gender", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\813472488.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\813472488.py:8: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Berdasarkan Kelompok Usia

# %%
byage_df = all_df.groupby(by="age_group").customer_id.nunique().reset_index()
byage_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
byage_df
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ["Youth", "Adults", "Seniors"])
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
 
sns.barplot(
    y="customer_count", 
    x="age_group",
    data=byage_df.sort_values(by="age_group", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by Age", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\3649207529.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\3649207529.py:10: UserWarning: The palette list has more values (5) than needed (3), which may not be intended.
#   sns.barplot(

# %% [markdown]
# ### Berdasarkan State

# %%
bystate_df = all_df.groupby(by="state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count", 
    y="state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\2675487988.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ## 4. Kapan terakhir pelanggan melakukan transaksi?
# ## 5. Seberapa sering seorang pelanggan melakukan pembelian dalam beberapa bulan terakhir?
# ## 6. Berapa banyak uang yang dihabiskan pelanggan dalam beberapa bulan terakhir?

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_date": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "total_price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]
 
# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)
 
rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))
 
colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]
 
sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)
 
sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)
 
sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)
 
plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\1210342829.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\1210342829.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# C:\Users\ANDIK\AppData\Local\Temp\ipykernel_3736\1210342829.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])

# %%
all_df.to_csv("all_data.csv", index=False)
